# %%
import pandas as pd

# %%
def get_day_number(date_):
    value_day = int(date_.split(' ')[0])
    return value_day

# %%
def check_par(number):
    if number%2 ==  0:
        return True
    else:
        return False

# %%
df = pd.read_csv('files/Nerismar_Febres_2021-09-13_09_21_00.597943.csv')

# %%
df
# Out:
#         autor_post                                          url_autor  \
# 0  Nerismar Febres  https://www.facebook.com/nerismar.febres?__cft...
# 1  Nerismar Febres  https://www.facebook.com/nerismar.febres?__cft...
# 2  Nerismar Febres  https://www.facebook.com/nerismar.febres?__cft...
# 3  Nerismar Febres  https://www.facebook.com/nerismar.febres?__cft...
# 4  Nerismar Febres  https://www.facebook.com/nerismar.febres?__cft...
# 5  Nerismar Febres  https://www.facebook.com/nerismar.febres?__cft...
# 6  Nerismar Febres  https://www.facebook.com/nerismar.febres?__cft...
# 7  Nerismar Febres  https://www.facebook.com/nerismar.febres?__cft...
# 8  Nerismar Febres  https://www.facebook.com/nerismar.febres?__cft...
# 9  Nerismar Febres  https://www.facebook.com/nerismar.febres?__cft...
#
#           date_post            descripcion_post  autor_post_shared  \
# 0  13 de Septiembre                         NaN                 4K
# ...

# %%
df_whit_par = df[df['date_post'].apply(get_day_number).apply(check_par)]

# %%
df_whit_par
# Out:
#         autor_post                                          url_autor  \
# 5  Nerismar Febres  https://www.facebook.com/nerismar.febres?__cft...
# 6  Nerismar Febres  https://www.facebook.com/nerismar.febres?__cft...
# 7  Nerismar Febres  https://www.facebook.com/nerismar.febres?__cft...
# 8  Nerismar Febres  https://www.facebook.com/nerismar.febres?__cft...
# 9  Nerismar Febres  https://www.facebook.com/nerismar.febres?__cft...
#
#           date_post   descripcion_post  autor_post_shared  \
# 5  12 de Septiembre               Real                Mia
# 6  12 de Septiembre  Flaquita perfecta       NOT ASSIGNED
# 7  12 de Septiembre            Es real  Dilo con dibujos.
# 8  12 de Septiembre  jajajajajajaja ve          Joss Bell
# 9  12 de Septiembre       NOT ASSIGNED         Pendejoboy
#
#                                     url_autor_shared  \
# 5  https://www.facebook.com/mia.rico.7771?__cft__...
# 6                                       NOT ASSIGNED
# ...
